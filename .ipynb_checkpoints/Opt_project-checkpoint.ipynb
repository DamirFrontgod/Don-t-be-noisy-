# %% [markdown]
# # Не шуми!

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import random
import scipy.io
from scipy.optimize import minimize
from scipy.optimize import check_grad
import pandas as pd

# %% [markdown]
# ### Функция, удаляющая шумы
# #### Принимает:
# xcor - массив точек
# eps - эпсилон, задающий шум
# #### Возвращает:
# Новый массив без шумов
# #### Примечание:
# работает в предположении о том, что xcor - list

# %%
def delnoize(xcor, eps):
    bcount = math.ceil(0.008*len(xcor))
    i = 1
    lst = []
    while i < len(xcor):
        
        norm = xcor[i-1]
        noize = False
        
        if abs(xcor[i] - norm) > eps:
            j = 0
            noize = False
            while j < bcount:
                if abs(xcor[i+j] - norm) < eps:
                    noize = True
                    break
                j = j + 1
                
        if noize:
            lst.append([i, i+j-1])
            i = i + j
        else:
            i = i + 1
            
    i = len(lst) - 1

    while i >= 0:
        a = lst[i][0]
        b = lst[i][1]
        for k in range(0, b-a+1):
            xcor.pop(a)
        i = i - 1
        
    return xcor

# %% [markdown]
# ### Функция, обнаруживающая разрывы
# #### Принимает:
# Параметры аналогичны предыдущей функции
# #### Возвращает:
# Возвращает список разрывов
# #### Примечание:
# Работает в предположении об отсутсвии шумов

# %%
def foundgap(xcor, eps): 
    i = 1
    lst = []
    while i < len(xcor):
        norm = xcor[i-1]
        if abs(xcor[i] - norm) > eps:
            lst.append(i-1)
        i = i + 1
    return lst

# %% [markdown]
# ### Генератор сигналов для проверки масштабируемости
# #### Принимает:
# eps - максимальная разница между соседними точками вне шумов (10 * eps - размер шумов)
# N - количество точек
# section_list - отрезки, на которых определены функции
# f_list - собственно сами функции
# #### Возвращает:
# Возвращает сигнал - массив точек

# %%
def advanced_generator(N, section_list, f_list,  eps):
    points = []
    
    for i in range(len(section_list)):
        section_start = int(section_list[i][0]) 
        section_end = int(section_list[i][1])
        for j in range(section_start, section_end + 1):
            points.append(f_list[i](j) + random.uniform(0, eps))
    
    noises_indexes = sorted([random.randrange(0, N) for i in range(0, 6)])
    for i in noises_indexes:
        noises_num = random.randrange(5, 30)
        direction = random.randrange(-1, 2)
        step_size = random.uniform(4 * eps, 10 * eps)
        for j in range(0, noises_num):
            points[i + j] += direction * step_size
    return points

# %% [markdown]
# ### Зададим параметры для генератора

# %%
N = 5000
section_list_gen_raw = [[0, 1000], 
                [1001, 3000], 
                [3001, 4000], 
                [4001, 4999]]
f_list = [lambda x: 0.05*x**0.5,
          lambda x: 0.5, 
          lambda x: 1,
          lambda x: 0]
eps_fluct = 0.04
eps = 0.6

# %% [markdown]
# ### Перед тем как пользоваться методами

# %% [markdown]
# #### Выгружаем данные

# %%
data = scipy.io.loadmat('denoising_data.mat')
y_raw = data['xcor']
x_raw = np.arange(1, y_raw.shape[0] + 1)
plt.plot(x_raw, y_raw)
plt.show()

# %% [markdown]
# #### Очищаем от шумов и ищем отрезки непрерывности

# %%
eps = 0.1
def cleanAndSectionSearch(eps, y_raw):
    
    y_raw_list = [y_raw[i][0] for i in range(y_raw.shape[0])]
    y_clean_list = delnoize(y_raw_list, eps)

    y = np.asarray([[item] for item in y_clean_list])
    N = y.shape[0]
    x = np.arange(N)/5000

    gaps = [0]
    gaps.extend(foundgap(y_clean_list, eps))
    gaps.append(N-1)
    section_list = [[gaps[i]+1, gaps[i+1]] for i in range(len(gaps)-1)]
    section_list[0][0] = 0
    return y, x, section_list

y, x, section_list = cleanAndSectionSearch(eps, y_raw)
plt.plot(x, y)
plt.title("Данные без шумов")
plt.show()
print("Участки непрерывности", section_list)

y_gen_raw = advanced_generator(N, section_list_gen_raw, f_list, eps_fluct)
plt.plot(y_gen_raw)
plt.title("Данные генератора")
plt.show()
y_gen_raw = np.asarray([y_gen_raw]).T
y_gen, x_gen, section_list_gen = cleanAndSectionSearch(eps, y_gen_raw)
plt.plot(x_gen, y_gen)
plt.title("Данные генератора без шумов")
plt.show()
print("Участки непрерывности", section_list_gen)
# Out:
# Участки непрерывности [[0, 986], [987, 4888]]
# Участки непрерывности [[0, 958], [959, 2942], [2943, 3932], [3933, 4931]]

# %% [markdown]
# ## Явное решение:

# %% [markdown]
# #### Создаем матрицу признаков

# %%
def createF5(N):
    x = np.arange(N)/5000
    df = pd.DataFrame()
    df['x'] = x / 100
    features = {'const':lambda x: 1, 'x': lambda x: x, 'x^2': lambda x: x**2, 'x^3': lambda x: x**3, 'x^4': lambda x: x**4, 
                'x^5': lambda x: x**5}

    for item in features.items():
        df[item[0]] = df['x'].apply(item[1])
    return df

# %% [markdown]
# #### На каждом участке приравниваем градиент среднеквадратичной ошибки к нулю и находим явное решение

# %%
F = createF5(y.shape[0])
F_gen = createF10(y_gen.shape[0])

def explicitSolver(y, section_list, F):
    final = []
    for i in range(len(section_list)):
        y_curr = y[section_list[i][0]: section_list[i][1] + 1]
        F_curr = F[section_list[i][0]: section_list[i][1] + 1]
        FtF_inv = np.linalg.inv(F_curr.T.dot(F_curr))
        w = FtF_inv.dot(F_curr.T).dot(y_curr)
        y_pred = F_curr.dot(w)
#         print(np.linalg.norm(y_curr - y_pred))
        final.append(y_pred)
    final = np.concatenate(final)
    return final

result = explicitSolver(y, section_list, F)
plt.plot(y, 'b')
plt.plot(result, 'y')
plt.show()

result_gen = explicitSolver(y_gen, section_list_gen, F_gen)
plt.plot(y_gen, 'b')
plt.plot(result_gen, 'y')
plt.show()

# %% [markdown]
# ## Метод градиентного спуска:

# %% [markdown]
# ### Введем функцию ошибки и ее градиент

# %%
def Q(y, F, w):
    Y = y.reshape(-1,)
    return np.sum((np.dot(F, w) - Y)**2)

def gradQ(y, F, w):
    Y = y.reshape(-1,)
    return np.dot(F.T, np.dot(F, w) - Y) / Y.shape[0]

# %% [markdown]
# ### Сам метод

# %%
def GC(F, y, eta, eps, max_iter):
    loss = []
    w = np.zeros(F.shape[1])
    for i in range(max_iter):
        grad = gradQ(y, F, w)
        if (np.linalg.norm(grad) < eps):
            break
        w -= eta * gradQ(y, F, w)
        loss.append(Q(y, F, w))
    return loss, w

# %%
def createF10(N):
    x = np.arange(N)/5000
    df = pd.DataFrame()
    df['x'] = x
    features = {'const':lambda x: 1, 'x': lambda x: x, 'x^2': lambda x: x**2, 'x^3': lambda x: x**3, 'x^4': lambda x: x**4, 
                'x^5': lambda x: x**5, 'x^6': lambda x: x**6, 'x^7': lambda x: x**7, 'x^8': lambda x: x**8, 'x^9': lambda x: x**9}

    for item in features.items():
        df[item[0]] = df['x'].apply(item[1])
    return df.values

# %% [markdown]
# #### Тестируем

# %%
F = createF10(y.shape[0])
F_gen = createF5(y_gen.shape[0])

max_iter = 100000
eta = 1
eps = 1e-5

def GCSolver(y, section_list, F, eta, eps, max_iter):
    final = []
    final_loss = []
    for i in range(len(section_list)):
        y_curr = y[section_list[i][0]: section_list[i][1]+1]
        F_curr = F[section_list[i][0]: section_list[i][1]+1]
        loss, w = GC(F_curr, y_curr, eta, eps, max_iter)
        y_pred = F_curr.dot(w)
        final.append(y_pred)
        final_loss.append(loss)

    final = np.concatenate(final)
    final_loss = np.concatenate(final_loss)
    return final, final_loss

final, final_loss = GCSolver(y, section_list, F, eta, eps, max_iter)
plt.plot(y, 'b')
plt.plot(final, 'y')
plt.show()

final_gen, final_loss_gen = GCSolver(y_gen, section_list_gen, F_gen, eta, eps, max_iter)
plt.plot(y_gen, 'b')
plt.plot(final_gen, 'y')
plt.show()

# %% [markdown]
# Так и планировалось)

# %% [markdown]
# ## Аппроксимация при помощи minimize и добавления степеней:

# %%
eps = 0.4
def mkPol(coff, x):
    pol = 0
    for dgr in range(0,len(coff)):
        pol += coff[dgr]*(x**dgr)
    return pol
def funcToMin(coff, tup):
    res = 0
    for i in range(tup[1],tup[2]):
        pol = mkPol(coff, i)
        res += (tup[0][i]-pol)**2
    return res
def polyGain(y, lst, eps):
    xcor = []
    for i in range(0, len(y)): xcor.append(y[i])
    arr = []
    for k in range(0, len(lst)):
        left = lst[k][0]
        right = lst[k][1]
        err = 2*eps
        j = 1
        while err > eps:
            x0 = [0]*(j)
            res = minimize(funcToMin, x0, args = [xcor, left, right], method='Nelder-Mead', options={'xtol': 1e-2, 'disp': True})
            narr = []
            err = 0
            for i in range(left, right):
                nval = mkPol(res.x, i)
                if abs(nval-xcor[i]) > err: err = abs(nval-xcor[i])
                narr.append(nval)
            j += 1
            print("err: ", err)
        print("degree of polinom: ", len(res.x) - 1)
        arr += narr
    return arr
final = polyGain(y, section_list, eps)
plt.plot(y)
plt.plot(final)
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.548847
#          Iterations: 22
#          Function evaluations: 44
# err:  [0.0695411]
# degree of polinom:  0
# Optimization terminated successfully.
#          Current function value: 667.004512
#          Iterations: 15
#          Function evaluations: 30
# err:  [0.90163325]
# Optimization terminated successfully.
#          Current function value: 585.026800
#          Iterations: 49
#          Function evaluations: 91
# err:  [0.77106028]
# Optimization terminated successfully.
#          Current function value: 446.512935
#          Iterations: 151
#          Function evaluations: 273
# err:  [0.6339048]
# Optimization terminated successfully.
#          Current function value: 141.559102
#          Iterations: 271
#          Function evaluations: 470
# err:  [0.7078064]
# Optimization terminated successfully.
#          Current function value: 135.905484
#          Iterations: 438
#          Function evaluations: 720
# err:  [0.59453237]
# Optimization terminated successfully.
#          Current function value: 73.859103
#          Iterations: 362
#          Function evaluations: 615
# err:  [0.59327102]
# Optimization terminated successfully.
#          Current function value: 29.918003
#          Iterations: 333
#          Function evaluations: 601
# err:  [0.30636055]
# degree of polinom:  6

# %%
final = polyGain(y_gen, section_list_gen, 0.15)
plt.plot(y_gen)
plt.plot(final)
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 137.691396
#          Iterations: 20
#          Function evaluations: 40
# err:  [1.05037426]
# Optimization terminated successfully.
#          Current function value: 6.590611
#          Iterations: 56
#          Function evaluations: 106
# err:  [0.41045756]
# Optimization terminated successfully.
#          Current function value: 9.055693
#          Iterations: 65
#          Function evaluations: 126
# err:  [0.22620511]
# Optimization terminated successfully.
#          Current function value: 2.875392
#          Iterations: 137
#          Function evaluations: 248
# err:  [0.17466996]
# Optimization terminated successfully.
#          Current function value: 1.094146
#          Iterations: 279
#          Function evaluations: 472
# err:  [0.12112967]
# degree of polinom:  4
# Optimization terminated successfully.
#          Current function value: 0.274009
#          Iterations: 20
#          Function evaluations: 40
# err:  [0.02023774]
# degree of polinom:  0
# Optimization terminated successfully.
#          Current function value: 0.135076
#          Iterations: 23
#          Function evaluations: 46
# err:  [0.0199771]
# degree of polinom:  0
# Optimization terminated successfully.
#          Current function value: 0.129276
#          Iterations: 12
#          Function evaluations: 24
# err:  [0.02058542]
# degree of polinom:  0
